# %% [markdown]
# # HumanActivityRecognition
#
# <br>
#
#
# This project is to build a model that predicts the human activities such as Walking, Walking_Upstairs, Walking_Downstairs, Sitting, Standing or Laying.
#
# This dataset is collected from 30 persons(referred as subjects in this dataset), performing different activities with a smartphone to their waists. The data is recorded with the help of sensors (accelerometer and Gyroscope) in that smartphone. This experiment was video recorded to label the data manually.
#
# ## How data was recorded
#
# By using the sensors(Gyroscope and accelerometer) in a smartphone, they have captured '3-axial linear acceleration'(_tAcc-XYZ_) from accelerometer and '3-axial angular velocity' (_tGyro-XYZ_) from Gyroscope with several variations.
#
# > prefix 't' in those metrics denotes time.
#
# > suffix 'XYZ' represents 3-axial signals in X , Y, and Z directions.
#
# ### Feature names
#
# 1. These sensor signals are preprocessed by applying noise filters and then sampled in fixed-width windows(sliding windows) of 2.56 seconds each with 50% overlap. ie., each window has 128 readings.
#
# 2. From Each window, a feature vector was obtianed by calculating variables from the time and frequency domain.
# > In our dataset, each datapoint represents a window with different readings
# 3. The accelertion signal was saperated into Body and Gravity acceleration signals(___tBodyAcc-XYZ___ and ___tGravityAcc-XYZ___) using some low pass filter with corner frequecy of 0.3Hz.
#
# 4. After that, the body linear acceleration and angular velocity were derived in time to obtian _jerk signals_ (___tBodyAccJerk-XYZ___ and ___tBodyGyroJerk-XYZ___).
#
# 5. The magnitude of these 3-dimensional signals were calculated using the Euclidian norm. This magnitudes are represented as features with names like _tBodyAccMag_, _tGravityAccMag_, _tBodyAccJerkMag_, _tBodyGyroMag_ and _tBodyGyroJerkMag_.
#
# 6. Finally, We've got frequency domain signals from some of the available signals by applying a FFT (Fast Fourier Transform). These signals obtained were labeled with ___prefix 'f'___ just like original signals with ___prefix 't'___. These signals are labeled as ___fBodyAcc-XYZ___, ___fBodyGyroMag___ etc.,.
#
# 7. These are the signals that we got so far.
# 	+ tBodyAcc-XYZ
# 	+ tGravityAcc-XYZ
# 	+ tBodyAccJerk-XYZ
# 	+ tBodyGyro-XYZ
# 	+ tBodyGyroJerk-XYZ
# 	+ tBodyAccMag
# 	+ tGravityAccMag
# 	+ tBodyAccJerkMag
# 	+ tBodyGyroMag
# 	+ tBodyGyroJerkMag
# 	+ fBodyAcc-XYZ
# 	+ fBodyAccJerk-XYZ
# 	+ fBodyGyro-XYZ
# 	+ fBodyAccMag
# 	+ fBodyAccJerkMag
# 	+ fBodyGyroMag
# 	+ fBodyGyroJerkMag
#
# 8. We can esitmate some set of variables from the above signals. ie., We will estimate the following properties on each and every signal that we recoreded so far.
#
# 	+ ___mean()___: Mean value
# 	+ ___std()___: Standard deviation
# 	+ ___mad()___: Median absolute deviation
# 	+ ___max()___: Largest value in array
# 	+ ___min()___: Smallest value in array
# 	+ ___sma()___: Signal magnitude area
# 	+ ___energy()___: Energy measure. Sum of the squares divided by the number of values.
# 	+ ___iqr()___: Interquartile range
# 	+ ___entropy()___: Signal entropy
# 	+ ___arCoeff()___: Autorregresion coefficients with Burg order equal to 4
# 	+ ___correlation()___: correlation coefficient between two signals
# 	+ ___maxInds()___: index of the frequency component with largest magnitude
# 	+ ___meanFreq()___: Weighted average of the frequency components to obtain a mean frequency
# 	+ ___skewness()___: skewness of the frequency domain signal
# 	+ ___kurtosis()___: kurtosis of the frequency domain signal
# 	+ ___bandsEnergy()___: Energy of a frequency interval within the 64 bins of the FFT of each window.
# 	+ ___angle()___: Angle between to vectors.
#
# 9. We can obtain some other vectors by taking the average of signals in a single window sample. These are used on the angle() variable'
# `
# 	+ gravityMean
# 	+ tBodyAccMean
# 	+ tBodyAccJerkMean
# 	+ tBodyGyroMean
# 	+ tBodyGyroJerkMean
#
#
# ###  Y_Labels(Encoded)
# + In the dataset, Y_labels are represented as numbers from 1 to 6 as their identifiers.
#
# 	- WALKING as __1__
# 	- WALKING_UPSTAIRS as __2__
# 	- WALKING_DOWNSTAIRS as __3__
# 	- SITTING as __4__
# 	- STANDING as __5__
# 	- LAYING as __6__
#
# ## Train and test data were saperated
#  - The readings from ___70%___ of the volunteers were taken as ___trianing data___ and remaining ___30%___ subjects recordings were taken for ___test data___
#
# ## Data
#
# * All the data is present in 'UCI_HAR_dataset/' folder in present working directory.
#      - Feature names are present in 'UCI_HAR_dataset/features.txt'
#      - ___Train Data___
#          - 'UCI_HAR_dataset/train/X_train.txt'
#          - 'UCI_HAR_dataset/train/subject_train.txt'
#          - 'UCI_HAR_dataset/train/y_train.txt'
#      - ___Test Data___
#          - 'UCI_HAR_dataset/test/X_test.txt'
#          - 'UCI_HAR_dataset/test/subject_test.txt'
#          - 'UCI_HAR_dataset/test/y_test.txt'
#
#
# ## Data Size :
# > 27 MB

# %% [markdown]
# # Quick overview of the dataset :

# %% [markdown]
# * Accelerometer and Gyroscope readings are taken from 30 volunteers(referred as subjects) while performing the following 6 Activities.
#
#     1. Walking
#     2. WalkingUpstairs
#     3. WalkingDownstairs
#     4. Standing
#     5. Sitting
#     6. Lying.
#
#
# * Readings are divided into a window of 2.56 seconds with 50% overlapping.
#
# * Accelerometer readings are divided into gravity acceleration and body acceleration readings,
#   which has x,y and z components each.
#
# * Gyroscope readings are the measure of angular velocities which has x,y and z components.
#
# * Jerk signals are calculated for BodyAcceleration readings.
#
# * Fourier Transforms are made on the above time readings to obtain frequency readings.
#
# * Now, on all the base signal readings., mean, max, mad, sma, arcoefficient, engerybands,entropy etc., are calculated for each window.
#
# * We get a feature vector of 561 features and these features are given in the dataset.
#
# * Each window of readings is a datapoint of 561 features.
#
# ## Problem Framework
#
# * 30 subjects(volunteers) data is randomly split to 70%(21) test and 30%(7) train data.
# * Each datapoint corresponds one of the 6 Activities.

# %% [markdown]
# ## Problem Statement
#
#  + Given a new datapoint we have to predict the Activity

# %%
import numpy as np
import pandas as pd

# get the features from the file features.txt
features = list()
with open('UCI_HAR_Dataset/features.txt') as f:
    features = [line.split()[1] for line in f.readlines()]
print('No of Features: {}'.format(len(features)))
# Out:
# No of Features: 561

# %% [markdown]
# ## Obtain the  train data

# %%
pd.__version__
# Out:
# '1.4.2'

# %%
# get the data from txt files to pandas dataffame
X_train = pd.read_csv('UCI_HAR_Dataset/train/X_train.txt', delim_whitespace=True, header=None, encoding='latin-1')
X_train.columns = features
# add subject column to the dataframe
X_train['subject'] = pd.read_csv('UCI_HAR_Dataset/train/subject_train.txt', header=None, squeeze=True)

y_train = pd.read_csv('UCI_HAR_Dataset/train/y_train.txt', names=['Activity'], squeeze=True)
y_train_labels = y_train.map({1: 'WALKING', 2:'WALKING_UPSTAIRS',3:'WALKING_DOWNSTAIRS',\
                       4:'SITTING', 5:'STANDING',6:'LAYING'})

# put all columns in a single dataframe
train = X_train
train['Activity'] = y_train
train['ActivityName'] = y_train_labels
train.sample()
# Out:
# /tmp/ipykernel_5002/4266734044.py:5: FutureWarning: The squeeze argument has been deprecated and will be removed in a future version. Append .squeeze("columns") to the call to squeeze.
#
#
#   X_train['subject'] = pd.read_csv('UCI_HAR_Dataset/train/subject_train.txt', header=None, squeeze=True)
# /tmp/ipykernel_5002/4266734044.py:7: FutureWarning: The squeeze argument has been deprecated and will be removed in a future version. Append .squeeze("columns") to the call to squeeze.
#
#
#   y_train = pd.read_csv('UCI_HAR_Dataset/train/y_train.txt', names=['Activity'], squeeze=True)
#      tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  \
# 516           0.248609           0.009126          -0.147798
#
#      tBodyAcc-std()-X  tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  \
# 516         -0.207528          0.120866         -0.452633         -0.231258
#
#      tBodyAcc-mad()-Y  tBodyAcc-mad()-Z  tBodyAcc-max()-X  ...  \
# 516          0.040564         -0.420222         -0.130437  ...
#
#      angle(tBodyAccMean,gravity)  angle(tBodyAccJerkMean),gravityMean)  \
# 516                      0.29847                              0.786613
#
#      angle(tBodyGyroMean,gravityMean)  angle(tBodyGyroJerkMean,gravityMean)  \
# 516                         -0.933382                             -0.613181
#
#      angle(X,gravityMean)  angle(Y,gravityMean)  angle(Z,gravityMean)  \
# 516             -0.588231              0.362853              0.121092
#
#      subject  Activity      ActivityName
# 516        3         2  WALKING_UPSTAIRS
#
# [1 rows x 564 columns]

# %%
train.shape
# Out:
# (7352, 564)

# %% [markdown]
# ## Obtain the  test data

# %%
# get the data from txt files to pandas dataffame
X_test = pd.read_csv('UCI_HAR_Dataset/test/X_test.txt', delim_whitespace=True, header=None, encoding='latin-1')
X_test.columns = features

# add subject column to the dataframe
X_test['subject'] = pd.read_csv('UCI_HAR_Dataset/test/subject_test.txt', header=None, squeeze=True)

# get y labels from the txt file
y_test = pd.read_csv('UCI_HAR_Dataset/test/y_test.txt', names=['Activity'], squeeze=True)
y_test_labels = y_test.map({1: 'WALKING', 2:'WALKING_UPSTAIRS',3:'WALKING_DOWNSTAIRS',\
                       4:'SITTING', 5:'STANDING',6:'LAYING'})


# put all columns in a single dataframe
test = X_test
test['Activity'] = y_test
test['ActivityName'] = y_test_labels
test.sample()
# Out:
# /tmp/ipykernel_5002/1961147520.py:6: FutureWarning: The squeeze argument has been deprecated and will be removed in a future version. Append .squeeze("columns") to the call to squeeze.
#
#
#   X_test['subject'] = pd.read_csv('UCI_HAR_Dataset/test/subject_test.txt', header=None, squeeze=True)
# /tmp/ipykernel_5002/1961147520.py:9: FutureWarning: The squeeze argument has been deprecated and will be removed in a future version. Append .squeeze("columns") to the call to squeeze.
#
#
#   y_test = pd.read_csv('UCI_HAR_Dataset/test/y_test.txt', names=['Activity'], squeeze=True)
#       tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  \
# 2306            0.22969          -0.021353          -0.096718
#
#       tBodyAcc-std()-X  tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  \
# 2306         -0.989848          -0.98058         -0.978015         -0.991077
#
#       tBodyAcc-mad()-Y  tBodyAcc-mad()-Z  tBodyAcc-max()-X  ...  \
# 2306          -0.97824         -0.976465         -0.952357  ...
#
#       angle(tBodyAccMean,gravity)  angle(tBodyAccJerkMean),gravityMean)  \
# 2306                    -0.019304                              0.365746
#
#       angle(tBodyGyroMean,gravityMean)  angle(tBodyGyroJerkMean,gravityMean)  \
# 2306                          0.717773                             -0.128169
#
#       angle(X,gravityMean)  angle(Y,gravityMean)  angle(Z,gravityMean)  \
# 2306              0.602225             -0.584393             -0.419361
#
#       subject  Activity  ActivityName
# 2306       20         6        LAYING
#
# [1 rows x 564 columns]

# %%
test.shape
# Out:
# (2947, 564)

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# ## 1. Check for Duplicates

# %%
print('No of duplicates in train: {}'.format(sum(train.duplicated())))
print('No of duplicates in test : {}'.format(sum(test.duplicated())))
# Out:
# No of duplicates in train: 0
# No of duplicates in test : 0

# %% [markdown]
# ## 2. Checking for NaN/null values

# %%
print('We have {} NaN/Null values in train'.format(train.isnull().values.sum()))
print('We have {} NaN/Null values in test'.format(test.isnull().values.sum()))
# Out:
# We have 0 NaN/Null values in train
# We have 0 NaN/Null values in test

# %% [markdown]
# ## 3. Check for data imbalance

# %%
#!pip install seaborn

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style('whitegrid')
plt.rcParams['font.family'] = 'Dejavu Sans'

# %%
plt.figure(figsize=(16,8))
plt.title('Data provided by each user', fontsize=20)
sns.countplot(x='subject',hue='ActivityName', data = train)
plt.show()

# %% [markdown]
# > We have got almost same number of reading from all the subjects

# %%
plt.title('No of Datapoints per Activity', fontsize=15)
sns.countplot(train.ActivityName)
plt.xticks(rotation=90)
plt.show()
# Out:
# /home/prasun/anaconda3/envs/tensorflow/lib/python3.10/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# ### Observation
# > Our data is well balanced (almost)

# %% [markdown]
# ## 4. Changing feature names

# %%
columns = train.columns

# Removing '()' from column names
columns = columns.str.replace('[()]','')
columns = columns.str.replace('[-]', '')
columns = columns.str.replace('[,]','')

train.columns = columns
test.columns = columns

test.columns
# Out:
# /tmp/ipykernel_5002/71913079.py:4: FutureWarning: The default value of regex will change from True to False in a future version.
#   columns = columns.str.replace('[()]','')
# /tmp/ipykernel_5002/71913079.py:5: FutureWarning: The default value of regex will change from True to False in a future version.
#   columns = columns.str.replace('[-]', '')
# /tmp/ipykernel_5002/71913079.py:6: FutureWarning: The default value of regex will change from True to False in a future version.
#   columns = columns.str.replace('[,]','')
# Index(['tBodyAccmeanX', 'tBodyAccmeanY', 'tBodyAccmeanZ', 'tBodyAccstdX',
#        'tBodyAccstdY', 'tBodyAccstdZ', 'tBodyAccmadX', 'tBodyAccmadY',
#        'tBodyAccmadZ', 'tBodyAccmaxX',
#        ...
#        'angletBodyAccMeangravity', 'angletBodyAccJerkMeangravityMean',
#        'angletBodyGyroMeangravityMean', 'angletBodyGyroJerkMeangravityMean',
#        'angleXgravityMean', 'angleYgravityMean', 'angleZgravityMean',
#        'subject', 'Activity', 'ActivityName'],
#       dtype='object', length=564)

# %% [markdown]
# ## 5. Save this dataframe in a csv files

# %%
train.to_csv('UCI_HAR_Dataset/csv_files/train.csv', index=False)
test.to_csv('UCI_HAR_Dataset/csv_files/test.csv', index=False)

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# "___Without domain knowledge EDA has no meaning, without EDA a problem has no soul.___"

# %% [markdown]
# ### 1. Featuring Engineering from Domain Knowledge

# %% [markdown]
# + __Static and Dynamic Activities__
#
#     - In static activities (sit, stand, lie down) motion information will not be very useful.
# 	- In the dynamic activities (Walking, WalkingUpstairs,WalkingDownstairs) motion info will be significant.

# %% [markdown]
# ### 2. Stationary and Moving activities are completely different

# %%
sns.set_palette("Set1", desat=0.80)
facetgrid = sns.FacetGrid(train, hue='ActivityName', size=6,aspect=2)
facetgrid.map(sns.distplot,'tBodyAccMagmean', hist=False)\
    .add_legend()
plt.annotate("Stationary Activities", xy=(-0.956,17), xytext=(-0.9, 23), size=20,\
            va='center', ha='left',\
            arrowprops=dict(arrowstyle="simple",connectionstyle="arc3,rad=0.1"))

plt.annotate("Moving Activities", xy=(0,3), xytext=(0.2, 9), size=20,\
            va='center', ha='left',\
            arrowprops=dict(arrowstyle="simple",connectionstyle="arc3,rad=0.1"))
plt.show()
# Out:
# /home/prasun/anaconda3/envs/tensorflow/lib/python3.10/site-packages/seaborn/axisgrid.py:337: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# /home/prasun/anaconda3/envs/tensorflow/lib/python3.10/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/prasun/anaconda3/envs/tensorflow/lib/python3.10/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/prasun/anaconda3/envs/tensorflow/lib/python3.10/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/prasun/anaconda3/envs/tensorflow/lib/python3.10/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/prasun/anaconda3/envs/tensorflow/lib/python3.10/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/prasun/anaconda3/envs/tensorflow/lib/python3.10/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %%
# for plotting purposes taking datapoints of each activity to a different dataframe
df1 = train[train['Activity']==1]
df2 = train[train['Activity']==2]
df3 = train[train['Activity']==3]
df4 = train[train['Activity']==4]
df5 = train[train['Activity']==5]
df6 = train[train['Activity']==6]

plt.figure(figsize=(14,7))
plt.subplot(2,2,1)
plt.title('Stationary Activities(Zoomed in)')
sns.distplot(df4['tBodyAccMagmean'],color = 'r',hist = False, label = 'Sitting')
sns.distplot(df5['tBodyAccMagmean'],color = 'm',hist = False,label = 'Standing')
sns.distplot(df6['tBodyAccMagmean'],color = 'c',hist = False, label = 'Laying')
plt.axis([-1.01, -0.5, 0, 35])
plt.legend(loc='center')

plt.subplot(2,2,2)
plt.title('Moving Activities')
sns.distplot(df1['tBodyAccMagmean'],color = 'red',hist = False, label = 'Walking')
sns.distplot(df2['tBodyAccMagmean'],color = 'blue',hist = False,label = 'Walking Up')
sns.distplot(df3['tBodyAccMagmean'],color = 'green',hist = False, label = 'Walking down')
plt.legend(loc='center right')


plt.tight_layout()
plt.show()
# Out:
# /home/prasun/anaconda3/envs/tensorflow/lib/python3.10/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/prasun/anaconda3/envs/tensorflow/lib/python3.10/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/prasun/anaconda3/envs/tensorflow/lib/python3.10/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/prasun/anaconda3/envs/tensorflow/lib/python3.10/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/prasun/anaconda3/envs/tensorflow/lib/python3.10/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/prasun/anaconda3/envs/tensorflow/lib/python3.10/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ### 3. Magnitude of an acceleration can saperate it well

# %%
plt.figure(figsize=(7,7))
sns.boxplot(x='ActivityName', y='tBodyAccMagmean',data=train, showfliers=False, saturation=1)
plt.ylabel('Acceleration Magnitude mean')
plt.axhline(y=-0.7, xmin=0.1, xmax=0.9,dashes=(5,5), c='g')
plt.axhline(y=-0.05, xmin=0.4, dashes=(5,5), c='m')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# __ Observations__:
# - If tAccMean is < -0.8 then the Activities are either Standing or Sitting or Laying.
# - If tAccMean is > -0.6 then the Activities are either Walking or WalkingDownstairs or WalkingUpstairs.
# - If tAccMean > 0.0 then the Activity is WalkingDownstairs.
# - We can classify 75% the Acitivity labels with some errors.

# %% [markdown]
# ### 4. Position of GravityAccelerationComponants also matters

# %%
sns.boxplot(x='ActivityName', y='angleXgravityMean', data=train)
plt.axhline(y=0.08, xmin=0.1, xmax=0.9,c='m',dashes=(5,3))
plt.title('Angle between X-axis and Gravity_mean', fontsize=15)
plt.xticks(rotation = 40)
plt.show()

# %% [markdown]
# __ Observations__:
# * If angleX,gravityMean > 0 then Activity is Laying.
# * We can classify all datapoints belonging to Laying activity with just a single if else statement.

# %%
sns.boxplot(x='ActivityName', y='angleYgravityMean', data = train, showfliers=False)
plt.title('Angle between Y-axis and Gravity_mean', fontsize=15)
plt.xticks(rotation = 40)
plt.axhline(y=-0.22, xmin=0.1, xmax=0.8, dashes=(5,3), c='m')
plt.show()

# %% [markdown]
# # Apply t-sne on the data

# %%
import numpy as np
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# performs t-sne with different perplexity values and their repective plots..

def perform_tsne(X_data, y_data, perplexities, n_iter=1000, img_name_prefix='t-sne'):
        
    for index,perplexity in enumerate(perplexities):
        # perform t-sne
        print('\nperforming tsne with perplexity {} and with {} iterations at max'.format(perplexity, n_iter))
        X_reduced = TSNE(verbose=2, perplexity=perplexity).fit_transform(X_data)
        print('Done..')
        
        # prepare the data for seaborn         
        print('Creating plot for this t-sne visualization..')
        df = pd.DataFrame({'x':X_reduced[:,0], 'y':X_reduced[:,1] ,'label':y_data})
        
        # draw the plot in appropriate place in the grid
        sns.lmplot(data=df, x='x', y='y', hue='label', fit_reg=False, size=8,\
                   palette="Set1",markers=['^','v','s','o', '1','2'])
        plt.title("perplexity : {} and max_iter : {}".format(perplexity, n_iter))
        img_name = img_name_prefix + '_perp_{}_iter_{}.png'.format(perplexity, n_iter)
        print('saving this plot as image in present working directory...')
        plt.savefig(img_name)
        plt.show()
        print('Done')

# %%
X_pre_tsne = train.drop(['subject', 'Activity','ActivityName'], axis=1)
y_pre_tsne = train['ActivityName']
perform_tsne(X_data = X_pre_tsne,y_data=y_pre_tsne, perplexities =[2,5,10,20,50])
# Out:
# performing tsne with perplexity 2 and with 1000 iterations at max
# [t-SNE] Computing 7 nearest neighbors...
# [t-SNE] Indexed 7352 samples in 0.002s...
# /home/prasun/anaconda3/envs/tensorflow/lib/python3.10/site-packages/sklearn/manifold/_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# /home/prasun/anaconda3/envs/tensorflow/lib/python3.10/site-packages/sklearn/manifold/_t_sne.py:790: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# [t-SNE] Computed neighbors for 7352 samples in 1.279s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 7352
# [t-SNE] Computed conditional probabilities for sample 2000 / 7352
# [t-SNE] Computed conditional probabilities for sample 3000 / 7352
# [t-SNE] Computed conditional probabilities for sample 4000 / 7352
# [t-SNE] Computed conditional probabilities for sample 5000 / 7352
# [t-SNE] Computed conditional probabilities for sample 6000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7352 / 7352
# [t-SNE] Mean sigma: 0.597443
# [t-SNE] Computed conditional probabilities in 0.125s
# [t-SNE] Iteration 50: error = 124.8132401, gradient norm = 0.0269196 (50 iterations in 1.009s)
# [t-SNE] Iteration 100: error = 107.1481094, gradient norm = 0.0263018 (50 iterations in 0.699s)
# [t-SNE] Iteration 150: error = 100.8653641, gradient norm = 0.0201278 (50 iterations in 0.606s)
# [t-SNE] Iteration 200: error = 97.4962616, gradient norm = 0.0168083 (50 iterations in 0.606s)
# [t-SNE] Iteration 250: error = 95.2131653, gradient norm = 0.0157813 (50 iterations in 0.605s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 95.213165
# [t-SNE] Iteration 300: error = 4.1211891, gradient norm = 0.0015775 (50 iterations in 0.632s)
# [t-SNE] Iteration 350: error = 3.2098243, gradient norm = 0.0009992 (50 iterations in 0.686s)
# [t-SNE] Iteration 400: error = 2.7775383, gradient norm = 0.0007159 (50 iterations in 0.688s)
# [t-SNE] Iteration 450: error = 2.5128193, gradient norm = 0.0005671 (50 iterations in 0.891s)
# [t-SNE] Iteration 500: error = 2.3287003, gradient norm = 0.0004791 (50 iterations in 0.876s)
# [t-SNE] Iteration 550: error = 2.1902809, gradient norm = 0.0004127 (50 iterations in 0.770s)
# [t-SNE] Iteration 600: error = 2.0803943, gradient norm = 0.0003698 (50 iterations in 0.765s)
# [t-SNE] Iteration 650: error = 1.9903622, gradient norm = 0.0003282 (50 iterations in 0.797s)
# [t-SNE] Iteration 700: error = 1.9144324, gradient norm = 0.0003032 (50 iterations in 0.847s)
# [t-SNE] Iteration 750: error = 1.8494965, gradient norm = 0.0002764 (50 iterations in 0.844s)
# [t-SNE] Iteration 800: error = 1.7927780, gradient norm = 0.0002580 (50 iterations in 0.780s)
# [t-SNE] Iteration 850: error = 1.7427166, gradient norm = 0.0002387 (50 iterations in 0.870s)
# [t-SNE] Iteration 900: error = 1.6978986, gradient norm = 0.0002238 (50 iterations in 0.876s)
# [t-SNE] Iteration 950: error = 1.6576259, gradient norm = 0.0002131 (50 iterations in 0.888s)
# [t-SNE] Iteration 1000: error = 1.6210233, gradient norm = 0.0002005 (50 iterations in 0.826s)
# [t-SNE] KL divergence after 1000 iterations: 1.621023
# Done..
# Creating plot for this t-sne visualization..
# /home/prasun/anaconda3/envs/tensorflow/lib/python3.10/site-packages/seaborn/regression.py:581: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# saving this plot as image in present working directory...
# Done
#
# performing tsne with perplexity 5 and with 1000 iterations at max
# [t-SNE] Computing 16 nearest neighbors...
# [t-SNE] Indexed 7352 samples in 0.003s...
# /home/prasun/anaconda3/envs/tensorflow/lib/python3.10/site-packages/sklearn/manifold/_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# /home/prasun/anaconda3/envs/tensorflow/lib/python3.10/site-packages/sklearn/manifold/_t_sne.py:790: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# [t-SNE] Computed neighbors for 7352 samples in 1.212s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 7352
# [t-SNE] Computed conditional probabilities for sample 2000 / 7352
# [t-SNE] Computed conditional probabilities for sample 3000 / 7352
# [t-SNE] Computed conditional probabilities for sample 4000 / 7352
# [t-SNE] Computed conditional probabilities for sample 5000 / 7352
# [t-SNE] Computed conditional probabilities for sample 6000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7352 / 7352
# [t-SNE] Mean sigma: 0.961446
# [t-SNE] Computed conditional probabilities in 0.031s
# [t-SNE] Iteration 50: error = 114.1714478, gradient norm = 0.0203999 (50 iterations in 1.308s)
# [t-SNE] Iteration 100: error = 97.9236679, gradient norm = 0.0144168 (50 iterations in 1.069s)
# [t-SNE] Iteration 150: error = 93.3243103, gradient norm = 0.0095744 (50 iterations in 0.949s)
# [t-SNE] Iteration 200: error = 91.3135681, gradient norm = 0.0077038 (50 iterations in 0.956s)
# [t-SNE] Iteration 250: error = 90.1184006, gradient norm = 0.0054543 (50 iterations in 1.268s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 90.118401
# [t-SNE] Iteration 300: error = 3.5749612, gradient norm = 0.0014626 (50 iterations in 1.635s)
# [t-SNE] Iteration 350: error = 2.8170443, gradient norm = 0.0007468 (50 iterations in 1.060s)
# [t-SNE] Iteration 400: error = 2.4365535, gradient norm = 0.0005250 (50 iterations in 1.569s)
# [t-SNE] Iteration 450: error = 2.2187726, gradient norm = 0.0004048 (50 iterations in 1.890s)
# [t-SNE] Iteration 500: error = 2.0739422, gradient norm = 0.0003330 (50 iterations in 1.906s)
# [t-SNE] Iteration 550: error = 1.9684701, gradient norm = 0.0002845 (50 iterations in 1.835s)
# [t-SNE] Iteration 600: error = 1.8871982, gradient norm = 0.0002488 (50 iterations in 1.575s)
# [t-SNE] Iteration 650: error = 1.8216945, gradient norm = 0.0002191 (50 iterations in 1.789s)
# [t-SNE] Iteration 700: error = 1.7676878, gradient norm = 0.0001982 (50 iterations in 1.652s)
# [t-SNE] Iteration 750: error = 1.7220588, gradient norm = 0.0001809 (50 iterations in 1.584s)
# [t-SNE] Iteration 800: error = 1.6829915, gradient norm = 0.0001654 (50 iterations in 1.991s)
# [t-SNE] Iteration 850: error = 1.6491693, gradient norm = 0.0001539 (50 iterations in 1.586s)
# [t-SNE] Iteration 900: error = 1.6191525, gradient norm = 0.0001422 (50 iterations in 1.628s)
# [t-SNE] Iteration 950: error = 1.5926952, gradient norm = 0.0001327 (50 iterations in 1.626s)
# [t-SNE] Iteration 1000: error = 1.5689771, gradient norm = 0.0001250 (50 iterations in 1.588s)
# [t-SNE] KL divergence after 1000 iterations: 1.568977
# Done..
# Creating plot for this t-sne visualization..
# /home/prasun/anaconda3/envs/tensorflow/lib/python3.10/site-packages/seaborn/regression.py:581: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# saving this plot as image in present working directory...
# Done
#
# performing tsne with perplexity 10 and with 1000 iterations at max
# [t-SNE] Computing 31 nearest neighbors...
# [t-SNE] Indexed 7352 samples in 0.003s...
# /home/prasun/anaconda3/envs/tensorflow/lib/python3.10/site-packages/sklearn/manifold/_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# /home/prasun/anaconda3/envs/tensorflow/lib/python3.10/site-packages/sklearn/manifold/_t_sne.py:790: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# [t-SNE] Computed neighbors for 7352 samples in 1.549s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 7352
# [t-SNE] Computed conditional probabilities for sample 2000 / 7352
# [t-SNE] Computed conditional probabilities for sample 3000 / 7352
# [t-SNE] Computed conditional probabilities for sample 4000 / 7352
# [t-SNE] Computed conditional probabilities for sample 5000 / 7352
# [t-SNE] Computed conditional probabilities for sample 6000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7352 / 7352
# [t-SNE] Mean sigma: 1.133827
# [t-SNE] Computed conditional probabilities in 0.057s
# [t-SNE] Iteration 50: error = 105.8033676, gradient norm = 0.0217448 (50 iterations in 2.099s)
# [t-SNE] Iteration 100: error = 90.2158356, gradient norm = 0.0124928 (50 iterations in 1.892s)
# [t-SNE] Iteration 150: error = 87.2445374, gradient norm = 0.0057831 (50 iterations in 1.735s)
# [t-SNE] Iteration 200: error = 86.0283813, gradient norm = 0.0036445 (50 iterations in 1.750s)
# [t-SNE] Iteration 250: error = 85.3421021, gradient norm = 0.0031116 (50 iterations in 1.737s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 85.342102
# [t-SNE] Iteration 300: error = 3.1338398, gradient norm = 0.0013908 (50 iterations in 1.693s)
# [t-SNE] Iteration 350: error = 2.4889102, gradient norm = 0.0006491 (50 iterations in 1.579s)
# [t-SNE] Iteration 400: error = 2.1687756, gradient norm = 0.0004201 (50 iterations in 1.558s)
# [t-SNE] Iteration 450: error = 1.9844273, gradient norm = 0.0003127 (50 iterations in 1.666s)
# [t-SNE] Iteration 500: error = 1.8664310, gradient norm = 0.0002493 (50 iterations in 1.656s)
# [t-SNE] Iteration 550: error = 1.7834190, gradient norm = 0.0002082 (50 iterations in 1.647s)
# [t-SNE] Iteration 600: error = 1.7210617, gradient norm = 0.0001809 (50 iterations in 1.646s)
# [t-SNE] Iteration 650: error = 1.6720631, gradient norm = 0.0001598 (50 iterations in 1.748s)
# [t-SNE] Iteration 700: error = 1.6327090, gradient norm = 0.0001437 (50 iterations in 1.687s)
# [t-SNE] Iteration 750: error = 1.6002498, gradient norm = 0.0001300 (50 iterations in 1.631s)
# [t-SNE] Iteration 800: error = 1.5730296, gradient norm = 0.0001210 (50 iterations in 1.613s)
# [t-SNE] Iteration 850: error = 1.5503979, gradient norm = 0.0001094 (50 iterations in 1.775s)
# [t-SNE] Iteration 900: error = 1.5304532, gradient norm = 0.0001029 (50 iterations in 1.648s)
# [t-SNE] Iteration 950: error = 1.5127984, gradient norm = 0.0000967 (50 iterations in 1.619s)
# [t-SNE] Iteration 1000: error = 1.4974546, gradient norm = 0.0000916 (50 iterations in 1.590s)
# [t-SNE] KL divergence after 1000 iterations: 1.497455
# Done..
# Creating plot for this t-sne visualization..
# /home/prasun/anaconda3/envs/tensorflow/lib/python3.10/site-packages/seaborn/regression.py:581: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# saving this plot as image in present working directory...
# Done
#
# performing tsne with perplexity 20 and with 1000 iterations at max
# [t-SNE] Computing 61 nearest neighbors...
# [t-SNE] Indexed 7352 samples in 0.003s...
# /home/prasun/anaconda3/envs/tensorflow/lib/python3.10/site-packages/sklearn/manifold/_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# /home/prasun/anaconda3/envs/tensorflow/lib/python3.10/site-packages/sklearn/manifold/_t_sne.py:790: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# [t-SNE] Computed neighbors for 7352 samples in 1.622s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 7352
# [t-SNE] Computed conditional probabilities for sample 2000 / 7352
# [t-SNE] Computed conditional probabilities for sample 3000 / 7352
# [t-SNE] Computed conditional probabilities for sample 4000 / 7352
# [t-SNE] Computed conditional probabilities for sample 5000 / 7352
# [t-SNE] Computed conditional probabilities for sample 6000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7352 / 7352
# [t-SNE] Mean sigma: 1.274336
# [t-SNE] Computed conditional probabilities in 0.117s
# [t-SNE] Iteration 50: error = 97.4866409, gradient norm = 0.0206495 (50 iterations in 2.378s)
# [t-SNE] Iteration 100: error = 84.1053314, gradient norm = 0.0070381 (50 iterations in 2.116s)
# [t-SNE] Iteration 150: error = 82.0010376, gradient norm = 0.0039489 (50 iterations in 2.080s)
# [t-SNE] Iteration 200: error = 81.2251205, gradient norm = 0.0039436 (50 iterations in 2.067s)
# [t-SNE] Iteration 250: error = 80.8328857, gradient norm = 0.0018592 (50 iterations in 2.140s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 80.832886
# [t-SNE] Iteration 300: error = 2.6927555, gradient norm = 0.0013123 (50 iterations in 1.926s)
# [t-SNE] Iteration 350: error = 2.1602242, gradient norm = 0.0005750 (50 iterations in 1.851s)
# [t-SNE] Iteration 400: error = 1.9116703, gradient norm = 0.0003466 (50 iterations in 1.808s)
# [t-SNE] Iteration 450: error = 1.7663389, gradient norm = 0.0002467 (50 iterations in 1.877s)
# [t-SNE] Iteration 500: error = 1.6724085, gradient norm = 0.0001929 (50 iterations in 1.976s)
# [t-SNE] Iteration 550: error = 1.6083241, gradient norm = 0.0001567 (50 iterations in 1.922s)
# [t-SNE] Iteration 600: error = 1.5618681, gradient norm = 0.0001341 (50 iterations in 1.833s)
# [t-SNE] Iteration 650: error = 1.5267174, gradient norm = 0.0001173 (50 iterations in 1.747s)
# [t-SNE] Iteration 700: error = 1.4991889, gradient norm = 0.0001056 (50 iterations in 1.951s)
# [t-SNE] Iteration 750: error = 1.4774424, gradient norm = 0.0000950 (50 iterations in 1.848s)
# [t-SNE] Iteration 800: error = 1.4599042, gradient norm = 0.0000875 (50 iterations in 2.005s)
# [t-SNE] Iteration 850: error = 1.4454132, gradient norm = 0.0000836 (50 iterations in 1.780s)
# [t-SNE] Iteration 900: error = 1.4337437, gradient norm = 0.0000778 (50 iterations in 1.755s)
# [t-SNE] Iteration 950: error = 1.4238198, gradient norm = 0.0000731 (50 iterations in 1.784s)
# [t-SNE] Iteration 1000: error = 1.4154115, gradient norm = 0.0000685 (50 iterations in 1.689s)
# [t-SNE] KL divergence after 1000 iterations: 1.415411
# Done..
# Creating plot for this t-sne visualization..
# /home/prasun/anaconda3/envs/tensorflow/lib/python3.10/site-packages/seaborn/regression.py:581: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# saving this plot as image in present working directory...
# Done
#
# performing tsne with perplexity 50 and with 1000 iterations at max
# [t-SNE] Computing 151 nearest neighbors...
# [t-SNE] Indexed 7352 samples in 0.003s...
# /home/prasun/anaconda3/envs/tensorflow/lib/python3.10/site-packages/sklearn/manifold/_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# /home/prasun/anaconda3/envs/tensorflow/lib/python3.10/site-packages/sklearn/manifold/_t_sne.py:790: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# [t-SNE] Computed neighbors for 7352 samples in 1.726s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 7352
# [t-SNE] Computed conditional probabilities for sample 2000 / 7352
# [t-SNE] Computed conditional probabilities for sample 3000 / 7352
# [t-SNE] Computed conditional probabilities for sample 4000 / 7352
# [t-SNE] Computed conditional probabilities for sample 5000 / 7352
# [t-SNE] Computed conditional probabilities for sample 6000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7352 / 7352
# [t-SNE] Mean sigma: 1.437672
# [t-SNE] Computed conditional probabilities in 0.296s
# [t-SNE] Iteration 50: error = 86.5772171, gradient norm = 0.0199446 (50 iterations in 2.616s)
# [t-SNE] Iteration 100: error = 75.5392075, gradient norm = 0.0036911 (50 iterations in 2.475s)
# [t-SNE] Iteration 150: error = 74.6402359, gradient norm = 0.0023188 (50 iterations in 2.480s)
# [t-SNE] Iteration 200: error = 74.3001328, gradient norm = 0.0014284 (50 iterations in 2.395s)
# [t-SNE] Iteration 250: error = 74.1244583, gradient norm = 0.0013288 (50 iterations in 2.282s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 74.124458
# [t-SNE] Iteration 300: error = 2.1520448, gradient norm = 0.0011751 (50 iterations in 2.284s)
# [t-SNE] Iteration 350: error = 1.7544950, gradient norm = 0.0004900 (50 iterations in 2.289s)
# [t-SNE] Iteration 400: error = 1.5858995, gradient norm = 0.0002815 (50 iterations in 2.172s)
# [t-SNE] Iteration 450: error = 1.4917986, gradient norm = 0.0001900 (50 iterations in 2.106s)
# [t-SNE] Iteration 500: error = 1.4321402, gradient norm = 0.0001389 (50 iterations in 2.163s)
# [t-SNE] Iteration 550: error = 1.3909324, gradient norm = 0.0001135 (50 iterations in 2.293s)
# [t-SNE] Iteration 600: error = 1.3617989, gradient norm = 0.0000943 (50 iterations in 2.116s)
# [t-SNE] Iteration 650: error = 1.3406428, gradient norm = 0.0000824 (50 iterations in 2.371s)
# [t-SNE] Iteration 700: error = 1.3251104, gradient norm = 0.0000756 (50 iterations in 2.188s)
# [t-SNE] Iteration 750: error = 1.3133919, gradient norm = 0.0000694 (50 iterations in 2.150s)
# [t-SNE] Iteration 800: error = 1.3044884, gradient norm = 0.0000629 (50 iterations in 2.356s)
# [t-SNE] Iteration 850: error = 1.2974826, gradient norm = 0.0000609 (50 iterations in 2.239s)
# [t-SNE] Iteration 900: error = 1.2921126, gradient norm = 0.0000590 (50 iterations in 2.078s)
# [t-SNE] Iteration 950: error = 1.2879851, gradient norm = 0.0000592 (50 iterations in 2.032s)
# [t-SNE] Iteration 1000: error = 1.2847118, gradient norm = 0.0000537 (50 iterations in 2.198s)
# [t-SNE] KL divergence after 1000 iterations: 1.284712
# Done..
# Creating plot for this t-sne visualization..
# /home/prasun/anaconda3/envs/tensorflow/lib/python3.10/site-packages/seaborn/regression.py:581: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# saving this plot as image in present working directory...
# Done
